# %%
# import section 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# seccion de carga de datos
# base_df= pd.read_csv('..........) # aca cargamos nuestro dataset base

# %%
# Ejercicio 1 - Filtrar los meses donde temp_max es mayor a 35°C.
# df= base_df.copy() # copiamos el dataset base y trabajamos sobre eso, de manera a que siempre tengamos el original a la mano 





# plot de los resultados al final
